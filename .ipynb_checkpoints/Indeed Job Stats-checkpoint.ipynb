# %% [markdown]
# # <center> Program to analyze and find salary of a job profile
#
# I wrote this program so that it can scrape and analyze several jobs listed on Indeed.com or Indeed.ca in this case since I am in Canada and find the average salary of jobs. In addition to this, it also tells us which city in Canada has the maximum number of jobs and maximum salary. I have plotted all this using bar graph to make it visually easy to understand.

# %% [markdown]
#  Let's start by asking the user which job title he wants search for. First, we create a variable called <b> *job_title_1*</b> and store the user input in it

# %%
job_title_1 = input("Enter the Job Title: ")
# Out:
# Enter the Job Title: Data Scientist

# %% [markdown]
# #### Now let's import the required libries

# %%
from bs4 import BeautifulSoup
import requests
import matplotlib.pyplot as plt
from urllib.request import urlopen
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.cm as cm
import matplotlib.colors as colors
import time
print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# The way Indeed works is it takes the given user input, converts it to lower case and replaces the spaces with +. So we need to do the same.
#
# Let's convert the job title to lower case using <b>.lower()</b> method.
#
# Then, let's replace the spaces with + using <b>.repalce()</b> method.
#
# And then let's see how the output looks, <b>job_title_3</b> in this case.

# %%
job_title_2 = job_title_1.lower() # convert to lower case
job_title_3 = job_title_2.replace(' ', '+') # replace space with +
job_title_3
# Out:
# 'data+scientist'

# %% [markdown]
# In our case, since we are searching for <b>Data Scientist</b> the output looks good, <b>*data+scientist*</b>

# %% [markdown]
# Now let's write the code that can scrape Indeed.ca with our <b>*job_title_3*</b>
#
# Here we insert job_title_3 into our url using concatenate feature in python

# %%
url = 'https://www.indeed.ca/jobs?q='+job_title_3+'&l=canada'
page = requests.get(url)
soup = BeautifulSoup(page.text, "html.parser")
#print(soup.prettify())

# %% [markdown]
# Let's check the url that we just parsed, just to be sure.

# %%
url
# Out:
# 'https://www.indeed.ca/jobs?q=data+scientist&l=canada'

# %% [markdown]
# Now that we have the the url, let's write a function that will parse the url, extract the data and store it in a dataframe.
#
# In order to get a proper data set, we need to parse more than one page. So let's write the code to parse first 10 pages and store them in the same dataframe using <b>pd.concat</b> function.

# %%
def parse(url):
    html = requests.get(url)
    soup = BeautifulSoup(html.content, 'html.parser', from_encoding="utf-8")
    df = pd.DataFrame(columns=["Title","Location","Company","Salary"])
    for each in soup.find_all(class_= "result" ):
        time.sleep(5)
        try: 
            title = each.find(class_='jobtitle').text.replace('\n', '')
        except:
            title = 'None'
        try:
            location = each.find('span', {'class':"location" }).text.replace('\n', '')
        except:
            location = 'None'
        try: 
            company = each.find(class_='company').text.replace('\n', '')
        except:
            company = 'None'
        try:
            salary = each.find('span', {'class':'no-wrap'}).text.replace('\n', '')
        except:
            salary = 'None'
        #synopsis = each.find('span', {'class':'summary'}).text.replace('\n', '')
        df = df.append({'Title':title, 'Location':location, 'Company':company, 'Salary':salary}, ignore_index=True)
    return df
df1 = parse(url)
url_1 = url + "&start=20"
url_2 = url + "&start=40"
url_3 = url + "&start=60"
url_4 = url + "&start=80"
url_5 = url + "&start=100"
url_6 = url + "&start=120"
url_7 = url + "&start=140"
url_8 = url + "&start=160"
url_9 = url + "&start=180"
url_10 = url + "&start=200"

df2 = parse(url_1)
df3 = parse(url_2)
df4 = parse(url_3)
df5 = parse(url_4)
df6 = parse(url_5)
df7 = parse(url_6)
df8 = parse(url_7)
df9 = parse(url_8)
df10 = parse(url_9)
df11 = parse(url_10)

data1 = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11], axis=0, ignore_index=True)
data1.head()
# Out:
#                    Title       Location  \
# 0  Junior Data Scientist           None
# 1         DATA SCIENTIST           None
# 2         Data Scientist           None
# 3         Data Scientist         Canada
# 4         data scientist  Vancouver, BC
#
#                                              Company          Salary
# 0  Labour Market Information Council | Conseil de...            None
# 1                Business Development Bank of Canada            None
# 2                                    exactEarth Ltd.  $92,500 a year
# 3                                 Crestview Strategy            None
# 4                                ResponsiveAds, Inc.  $3,850 a month

# %%
data1.shape
# Out:
# (167, 4)

# %% [markdown]
# Once we have the dataset, we can see that it has a lot of stuff that we don't need like \n, $ etc. So let's clean up the data.
#
# When we check the data type of data1, we can see that <b>Salary</b> is stored as an object. In addition to that, Salary is defined as per year, per month, per week and per hour. In order for our analysis to work, we need to have salary displayed as per year and the column salary itself should be either <b>*float*</b> or <b>*int*</b>.

# %%
data1.dtypes # here, salary is an object
# Out:
# Title       object
# Location    object
# Company     object
# Salary      object
# dtype: object

# %%
data_sal_year_temp = data1[data1['Salary'].str.contains(' a year')].reset_index(drop=True)
data_sal_year_1a = data_sal_year_temp.replace(' a year', '', regex=True) # replace 'a year'
data_sal_year_1 = data_sal_year_1a.replace('\n', '', regex=True) # replace \n
data_sal_year_2 = data_sal_year_1.replace('[\$,)]', '', regex=True) # replace $
data_sal_year_3a = data_sal_year_2['Salary'].str.split('-', expand=True)
data_sal_year_3a.iloc[:, :] = data_sal_year_3a.iloc[:, :].astype('float')
data_sal_year_3b = data_sal_year_3a.sum(axis=1).astype('float')
data_sal_year_3c = (data_sal_year_3b/2)
data_sal_year_3 = data_sal_year_3c.astype('int')
data_sal_year_5 = pd.concat([data_sal_year_2, data_sal_year_3], axis=1, sort=True)
data_sal_year_6 = data_sal_year_5.drop(['Salary'], axis=1)

# %% [markdown]
# This segment takes the salary per month and converts it to per year

# %%
data_sal_month_temp = data1[data1['Salary'].str.contains(' a month')].reset_index(drop=True)
data_sal_month_1a = data_sal_month_temp.replace(' a month', '', regex=True)
data_sal_month_1 = data_sal_month_1a.replace('\n', '', regex=True)
data_sal_month_2 = data_sal_month_1.replace('[\$,)]', '', regex=True)
data_sal_month_3a = data_sal_month_2['Salary'].str.split('-', expand=True)
data_sal_month_3a.iloc[:, :] = data_sal_month_3a.iloc[:, :].astype('float')
data_sal_month_3b = data_sal_month_3a.sum(axis=1).astype('float')
data_sal_month_3c = (data_sal_month_3b/2) * 12
data_sal_month_3 = data_sal_month_3c.astype('int')
data_sal_month_5 = pd.concat([data_sal_month_2, data_sal_month_3], axis=1, sort=True)
data_sal_month_6 = data_sal_month_5.drop(['Salary'], axis=1)

# %% [markdown]
# This segment takes the salary per week and converts it to per year

# %%
data_sal_week_temp = data1[data1['Salary'].str.contains(' a week')].reset_index(drop=True)
data_sal_week_1a = data_sal_week_temp.replace(' a week', '', regex=True)
data_sal_week_1 = data_sal_week_1a.replace('\n', '', regex=True)
data_sal_week_2 = data_sal_week_1.replace('[\$,)]', '', regex=True)
data_sal_week_3a = data_sal_week_2['Salary'].str.split('-', expand=True)
data_sal_week_3a.iloc[:, :] = data_sal_week_3a.iloc[:, :].astype('float')
data_sal_week_3b = data_sal_week_3a.sum(axis=1).astype('float')
data_sal_week_3c = (data_sal_week_3b/2) * 52
data_sal_week_3 = data_sal_week_3c.astype('int')
data_sal_week_5 = pd.concat([data_sal_week_2, data_sal_week_3], axis=1, sort=True)
data_sal_week_6 = data_sal_week_5.drop(['Salary'], axis=1)

# %% [markdown]
# This segment takes the salary per hour and converts it to per year

# %%
data_sal_hour_temp = data1[data1['Salary'].str.contains(' an hour')].reset_index(drop=True)
data_sal_hour_1a = data_sal_hour_temp.replace(' an hour', '', regex=True)
data_sal_hour_1 = data_sal_hour_1a.replace('\n', '', regex=True)
data_sal_hour_2 = data_sal_hour_1.replace('[\$,)]', '', regex=True)
data_sal_hour_3a = data_sal_hour_2['Salary'].str.split('-', expand=True)
data_sal_hour_3a.iloc[:, :] = data_sal_hour_3a.iloc[:, :].astype('float')
data_sal_hour_3b = data_sal_hour_3a.sum(axis=1).astype('float')
data_sal_hour_3c = (data_sal_hour_3b/2) * 40 * 52
data_sal_hour_3 = data_sal_hour_3c.astype('int')
data_sal_hour_5 = pd.concat([data_sal_hour_2, data_sal_hour_3], axis=1, sort=True)
data_sal_hour_6 = data_sal_hour_5.drop(['Salary'], axis=1)

# %% [markdown]
# Let's sort the rows that don't have any salary mentioned and save them in <b>data_sal_none_temp</b>

# %%
data_sal_none_temp = data1[data1['Salary'].str.contains('None')].reset_index(drop=True)
data_sal_none_temp.head()
# Out:
#                    Title    Location  \
# 0  Junior Data Scientist        None
# 1         DATA SCIENTIST        None
# 2         Data Scientist      Canada
# 3  Data Scientist, eComm        None
# 4         Data Scientist  Regina, SK
#
#                                              Company Salary
# 0  Labour Market Information Council | Conseil de...   None
# 1                Business Development Bank of Canada   None
# 2                                 Crestview Strategy   None
# 3                                         Flow Water   None
# 4                               Conexus Credit Union   None

# %% [markdown]
# Now let's bring together our newly formed dataset and save it as <b>data_sal_all</b> and rename the table header as <b>Title</b>, <b>Location</b>, <b>Company</b> and <b>Salary</b>

# %%
data_sal_all = pd.concat([data_sal_year_6, data_sal_month_6, data_sal_week_6, data_sal_hour_6], axis=0, sort=True)
data_sal_all.columns = ['Title', 'Location', 'Company', 'Salary']
data_sal_all.sort_values(by='Salary',ascending=True, inplace=True)
data_sal_all.head()
# Out:
#                                  Title      Location  \
# 5                       Data Scientist    Concord ON
# 0                       data scientist  Vancouver BC
# 6   Technical Assistant / Data Analyst   Edmonton AB
# 15          Machine Learning Scientist   Montréal QC
# 4                       Data Scientist   Hamilton ON
#
#                                  Company  Salary
# 5           SalesGrowth Development Inc.   15000
# 0                     ResponsiveAds Inc.   23100
# 6      Corrosion Service Company Limited   24960
# 15                             Fluent.ai   40000
# 4   Hamilton Health Sciences Corporation   44834

# %% [markdown]
# Now, let's join the two data sets, <b>data_sal_all</b> and <b>data_sal_none_temp</b> and save them in <b>data_sal_all_1</b>

# %%
data_sal_all_1 = pd.concat([data_sal_all, data_sal_none_temp], axis=0, sort=True)
data_sal_all_1.head()
# Out:
#                                  Company      Location Salary  \
# 5           SalesGrowth Development Inc.    Concord ON  15000
# 0                     ResponsiveAds Inc.  Vancouver BC  23100
# 6      Corrosion Service Company Limited   Edmonton AB  24960
# 15                             Fluent.ai   Montréal QC  40000
# 4   Hamilton Health Sciences Corporation   Hamilton ON  44834
#
#                                  Title
# 5                       Data Scientist
# 0                       data scientist
# 6   Technical Assistant / Data Analyst
# 15          Machine Learning Scientist
# 4                       Data Scientist

# %% [markdown]
# Let's see the shape of <b>data_sal_all_1</b>

# %%
data_sal_all_1.shape
# Out:
# (167, 4)

# %% [markdown]
# The shape of <b>data_sal_all_1</b> is <b>(283, 5)</b> which is same as the shape of <b>data1</b>.
# This proves that we successfully managed to merge the 2 datasets without missing any row.

# %% [markdown]
# Now let's replace <b>'None'</b> values with <b>np.nan</b> and change the data type of <b>Salary</b> to *float*

# %%
data5a = data_sal_all_1.replace('None',np.nan, regex=True)
data5a['Salary'].astype('float')
# Out:
# 5       15000.0
# 0       23100.0
# 6       24960.0
# 15      40000.0
# 4       44834.0
# 2       44834.0
# 0       46250.0
# 27      46250.0
# 22      46250.0
# 12      46250.0
# 19      46250.0
# 7       46250.0
# 6       60861.0
# 24      67500.0
# 2       67500.0
# 3       67949.0
# 10      72264.0
# 14      91537.0
# 8       91537.0
# 26      91537.0
# 23      91537.0
# 20      91537.0
# 11      97500.0
# 25     100000.0
# 17     100000.0
# 4      100000.0
# 13     100000.0
# 9      100000.0
# 18     110000.0
# 21     112713.0
#          ...
# 98          NaN
# 99          NaN
# 100         NaN
# 101         NaN
# 102         NaN
# 103         NaN
# 104         NaN
# 105         NaN
# 106         NaN
# 107         NaN
# 108         NaN
# 109         NaN
# 110         NaN
# 111         NaN
# 112         NaN
# 113         NaN
# 114         NaN
# 115         NaN
# 116         NaN
# 117         NaN
# 118         NaN
# 119         NaN
# 120         NaN
# 121         NaN
# 122         NaN
# 123         NaN
# 124         NaN
# 125         NaN
# 126         NaN
# 127         NaN
# Name: Salary, Length: 167, dtype: float64

# %% [markdown]
# Now, let's find the mean of the the cell Sa;ary using the .mean() method

# %%
mean_1 = data5a['Salary'].mean()
mean_1
# Out:
# 83848.71794871795

# %% [markdown]
# We can now replace the np.nan cells with the mean salary obtained in the previous step.
#
# Let's also change the datatype to *int*

# %%
data5b = data5a['Salary'].replace(np.nan, mean_1)
data5ba = data5b.astype('int')

# %% [markdown]
# Let's concact this salary to our previous dataframe <b>data_sal_all_1</b>

# %%
data5c = pd.concat([data_sal_all_1, data5ba], axis=1)
data5c.reset_index()
# Out:
#      index                                            Company  \
# 0        5                       SalesGrowth Development Inc.
# 1        0                                 ResponsiveAds Inc.
# 2        6                  Corrosion Service Company Limited
# 3       15                                          Fluent.ai
# 4        4               Hamilton Health Sciences Corporation
# 5        2               Hamilton Health Sciences Corporation
# 6        0                                    exactEarth Ltd.
# 7       27                                    exactEarth Ltd.
# 8       22                                    exactEarth Ltd.
# 9       12                                    exactEarth Ltd.
# 10      19                                    exactEarth Ltd.
# 11       7                                    exactEarth Ltd.
# 12       6                Thames Valley District School Board
# 13      24                                            DocuPet
# 14       2                                            DocuPet
# 15       3                              University of Alberta
# 16      10                            Simon Fraser University
# 17      14                                           Boast.AI
# 18       8                                           Boast.AI
# 19      26                                           Boast.AI
# 20      23                                           Boast.AI
# 21      20                                           Boast.AI
# 22      11                                           Boast.AI
# 23      25                           Skycope Technologies Inc
# 24      17                                        Robert Half
# 25       4                                        Robert Half
# 26      13                           Skycope Technologies Inc
# 27       9                                        Robert Half
# 28      18                                       FutureFit AI
# 29      21                            Bluvec Technologies Inc
# ..     ...                                                ...
# 137     98                                               Citi
# 138     99                                           Facebook
# 139    100                                Aquatic Informatics
# 140    101  Labour Market Information Council | Conseil de...
# 141    102                           Loblaw Companies Limited
# 142    103                   Xanadu Quantum Technologies Inc.
# 143    104                   Concordia University of Edmonton
# 144    105               AltaML Inc./Janalta Interactive Inc.
# 145    106        Operating Company DEMONWARE (CANADA) , INC.
# 146    107                           Loblaw Companies Limited
# 147    108                                           Interset
# 148    109                               Avrij Analytics Inc.
# 149    110                                          nugget.ai
# 150    111                                           Manulife
# 151    112                                           MobSquad
# 152    113                                    Natural Factors
# 153    114                                          Worximity
# 154    115                                        Bell Canada
# 155    116                                       Global Relay
# 156    117                                         Element AI
# 157    118                           Loblaw Companies Limited
# 158    119                                         Element AI
# 159    120                   Xanadu Quantum Technologies Inc.
# 160    121                                           Mappedin
# 161    122        Operating Company DEMONWARE (CANADA) , INC.
# 162    123                                      Mattamy Homes
# 163    124                                              Noise
# 164    125                                     CMLS Financial
# 165    126                              BLCTO Bell Labs & CTO
# 166    127  Labour Market Information Council | Conseil de...
#
#             Location  Salary  \
# 0         Concord ON   15000
# 1       Vancouver BC   23100
# 2        Edmonton AB   24960
# 3        Montréal QC   40000
# 4        Hamilton ON   44834
# 5        Hamilton ON   44834
# 6               None   46250
# 7               None   46250
# 8               None   46250
# 9               None   46250
# 10              None   46250
# 11              None   46250
# 12         London ON   60861
# 13              None   67500
# 14       Kingston ON   67500
# 15       Edmonton AB   67949
# 16        Burnaby BC   72264
# 17              None   91537
# 18              None   91537
# 19              None   91537
# 20              None   91537
# 21              None   91537
# 22        Toronto ON   97500
# 23              None  100000
# 24              None  100000
# 25              None  100000
# 26              None  100000
# 27              None  100000
# 28        Toronto ON  110000
# 29        Burnaby BC  112713
# ..               ...     ...
# 137  Mississauga, ON    None
# 138     Montréal, QC    None
# 139             None    None
# 140             None    None
# 141     Brampton, ON    None
# 142      Toronto, ON    None
# 143     Edmonton, AB    None
# 144     Edmonton, AB    None
# 145    Vancouver, BC    None
# 146     Brampton, ON    None
# 147       Ottawa, ON    None
# 148       Ottawa, ON    None
# 149      Toronto, ON    None
# 150      Toronto, ON    None
# 151    Vancouver, BC    None
# 152    Coquitlam, BC    None
# 153     Montréal, QC    None
# 154     Montréal, QC    None
# 155    Vancouver, BC    None
# 156      Toronto, ON    None
# 157     Brampton, ON    None
# 158     Montréal, QC    None
# 159      Toronto, ON    None
# 160     Waterloo, ON    None
# 161    Vancouver, BC    None
# 162       Milton, ON    None
# 163    Vancouver, BC    None
# 164    Vancouver, BC    None
# 165       Ottawa, ON    None
# 166             None    None
#
#                                                  Title  Salary
# 0                                       Data Scientist   15000
# 1                                       data scientist   23100
# 2                   Technical Assistant / Data Analyst   24960
# 3                           Machine Learning Scientist   40000
# 4                                       Data Scientist   44834
# 5                                       Data Scientist   44834
# 6                                       Data Scientist   46250
# 7                                       Data Scientist   46250
# 8                                       Data Scientist   46250
# 9                                       Data Scientist   46250
# 10                                      Data Scientist   46250
# 11                                      Data Scientist   46250
# 12                   Data and Visualization Specialist   60861
# 13                                      Data Scientist   67500
# 14                                      Data Scientist   67500
# 15                           Geospatial Data Scientist   67949
# 16                                Quantitative Analyst   72264
# 17                           Machine Learning Engineer   91537
# 18                           Machine Learning Engineer   91537
# 19                           Machine Learning Engineer   91537
# 20                           Machine Learning Engineer   91537
# 21                           Machine Learning Engineer   91537
# 22                           Machine Learning Engineer   97500
# 23                           Machine Learning Engineer  100000
# 24                                      Data Scientist  100000
# 25                                      Data Scientist  100000
# 26                           Machine Learning Engineer  100000
# 27                                      Data Scientist  100000
# 28                                Head of Data Science  110000
# 29                           Machine Learning Engineer  112713
# ..                                                 ...     ...
# 137                            Senior ETL/Data Analyst   83848
# 138                             Research Scientist, AI   83848
# 139                              Senior Data Scientist   83848
# 140                              Junior Data Scientist   83848
# 141      Senior Data Scientist, Pricing and Promotions   83848
# 142                     Machine Learning/Data Engineer   83848
# 143  Artificial Intelligence / Machine Learning Dev...   83848
# 144            Machine Learning Developer - AlphaLayer   83848
# 145                  Senior Matchmaking Data Scientist   83848
# 146  Senior Director, Machine Learning and Analytic...   83848
# 147                      Big Data Engineer - Analytics   83848
# 148                                       Statistician   83848
# 149                          Machine Learning Engineer   83848
# 150              Senior Data Scientist-Fraud Analytics   83848
# 151                          Machine Learning Engineer   83848
# 152         Master Data Management Projects Specialist   83848
# 153                                       BI Developer   83848
# 154  QC - 2021 Customer Operations Graduate Leaders...   83848
# 155           Technical Program Manager - Data Science   83848
# 156  Chercheuse/Chercheur scientifique, recherche a...   83848
# 157      Senior Data Scientist, Pricing and Promotions   83848
# 158  Chercheuse/Chercheur scientifique, recherche a...   83848
# 159                     Machine Learning/Data Engineer   83848
# 160              Software Developer - Machine Learning   83848
# 161                  Senior Matchmaking Data Scientist   83848
# 162          Associate, Building Information Analytics   83848
# 163                                   BI/Media Analyst   83848
# 164           Market Analyst, Mortgage Analytics Group   83848
# 165            Machine Learning Researcher - Bell Labs   83848
# 166                              Junior Data Scientist   83848
#
# [167 rows x 6 columns]

# %% [markdown]
# Now we have two Salary columns in our dataframe, so we rename the old one to Salary_1 and drop it.

# %%
data5c.columns = ['Company', 'Location', 'Salary_1', 'Title', 'Salary']
data5d = data5c.drop(['Salary_1'], axis=1)
data5d.head()
# Out:
#                                  Company      Location  \
# 5           SalesGrowth Development Inc.    Concord ON
# 0                     ResponsiveAds Inc.  Vancouver BC
# 6      Corrosion Service Company Limited   Edmonton AB
# 15                             Fluent.ai   Montréal QC
# 4   Hamilton Health Sciences Corporation   Hamilton ON
#
#                                  Title  Salary
# 5                       Data Scientist   15000
# 0                       data scientist   23100
# 6   Technical Assistant / Data Analyst   24960
# 15          Machine Learning Scientist   40000
# 4                       Data Scientist   44834

# %% [markdown]
# Let's procede with the cleanup of our dataset. Let's drop the cells that don't have any location as it won't be useful to us in our analysis.

# %%
data6a = data5d.replace('None',np.nan, regex=True)
data6 = data6a[pd.notnull(data5d["Location"])]
data6 = data6.reset_index(drop=True)
data7 = data6.groupby('Location').count()
sort_data = data7.sort_values('Title',ascending=False)

# %%
sort_data.head(10)
# Out:
#                  Company  Title  Salary
# Location
# Toronto, ON           32     32      32
# Vancouver, BC         19     19      19
# Montréal, QC          19     19      19
# Ottawa, ON             8      8       8
# Calgary, AB            6      6       6
# Brampton, ON           3      3       3
# London ON              3      3       3
# Mississauga, ON        3      3       3
# Vancouver BC           2      2       2
# Toronto ON             2      2       2

# %% [markdown]
# As we can see above, <b>sort_data</b> has a location <b>Canada</b>. We need to drop that row. Since we made our code flexible by asking the user to input his job title, this field might not show up in other job titles. Hence we need to write the code that will check if this field is there, and if it, drop it, else procede without doing anything.

# %%
sort_data_canada_1 = sort_data.reset_index()
sort_data_canada_2 = sort_data_canada_1.iloc[:, 0]
sort_data_canada_3 = sort_data_canada_2.isin(['Canada'])

# %%
if sort_data_canada_3.any() == True:
    sort_data_1 = sort_data.drop(['Canada'], axis=0)
else:
    sort_data_1 = sort_data

# %%
sort_data_2 = sort_data_1.reset_index()
sort_data_2.head()
# Out:
#         Location  Company  Title  Salary
# 0    Toronto, ON       32     32      32
# 1  Vancouver, BC       19     19      19
# 2   Montréal, QC       19     19      19
# 3     Ottawa, ON        8      8       8
# 4    Calgary, AB        6      6       6

# %% [markdown]
# Now let's split the location into <b>City</b> and <b>Provience</b>

# %%
data1 = sort_data_2['Location'].str.split(',', expand=True)
data1.columns = ['City', 'Provience']
data1.head()
# Out:
#         City Provience
# 0    Toronto        ON
# 1  Vancouver        BC
# 2   Montréal        QC
# 3     Ottawa        ON
# 4    Calgary        AB

# %% [markdown]
# Now let's merge this new data with the previous data and drop the column <b>Location</b>

# %%
data2 = pd.concat([data1, sort_data_2], axis=1, sort=False)
data3 = data2.drop(['Location'], axis=1)
data3.head()
# Out:
#         City Provience  Company  Title  Salary
# 0    Toronto        ON       32     32      32
# 1  Vancouver        BC       19     19      19
# 2   Montréal        QC       19     19      19
# 3     Ottawa        ON        8      8       8
# 4    Calgary        AB        6      6       6

# %% [markdown]
# Let's see which <b>Provience</b> has the maximum number of jobs.

# %%
data4 = data3.groupby('Provience')['Title'].apply(lambda x: ', '.join(x.astype(str))).reset_index()
data5 = data4['Title'].str.split(',', expand=True)
data5.iloc[:, :] = data5.iloc[:, :].astype(float)
data5['Total'] = data5.sum(axis=1).astype(int)
data8 = data5.loc[:, 'Total']
data9 = data4.loc[:, 'Provience']
data10 = pd.concat([data9, data8], axis=1, sort=True)
data10
# Out:
#   Provience  Total
# 0        AB      8
# 1        BC     23
# 2        NB      3
# 3        NL      2
# 4        ON     53
# 5        QC     23
# 6        SK      1

# %% [markdown]
# Let's sort the dataframe by which <b>City</b> has the maximum number of jobs and arrange it in ascending order.

# %%
data11 = sort_data_1
data11.sort_values(by='Title', ascending=True, inplace=True)
data12 = data11.loc[:, 'Title']
data13 = data12.tail(15)
data13
# Out:
# Location
# Moncton, NB         2
# Quebec City, QC     2
# Remote              2
# St. John's, NL      2
# Toronto ON          2
# Vancouver BC        2
# Burnaby BC          2
# Mississauga, ON     3
# London ON           3
# Brampton, ON        3
# Calgary, AB         6
# Ottawa, ON          8
# Montréal, QC       19
# Vancouver, BC      19
# Toronto, ON        32
# Name: Title, dtype: int64

# %% [markdown]
# Now let's make sure we don't have any duplicated in our dataframe

# %%
data5d.drop_duplicates(keep=False,inplace=True)
data5d.head()
# Out:
#                                 Company      Location  \
# 5          SalesGrowth Development Inc.    Concord ON
# 0                    ResponsiveAds Inc.  Vancouver BC
# 6     Corrosion Service Company Limited   Edmonton AB
# 15                            Fluent.ai   Montréal QC
# 6   Thames Valley District School Board     London ON
#
#                                  Title  Salary
# 5                       Data Scientist   15000
# 0                       data scientist   23100
# 6   Technical Assistant / Data Analyst   24960
# 15          Machine Learning Scientist   40000
# 6    Data and Visualization Specialist   60861

# %% [markdown]
# As we can see, many job titles have the same salary listed. For our last step, data visualization, we don’t need same salaries for different job titles, we just need one. So we group them by salary and then sort them in ascending order.

# %%
data5e = data5d.groupby('Salary')['Company'].apply(' '.join).reset_index()
data5e.sort_values(by='Salary', ascending=True, inplace=True)

# %%
data_sal_all_1 = data5e.loc[:,'Salary']
data_sal_all_2 = data_sal_all_1.tail(15)
data_sal_all_2
# Out:
# 0      15000
# 1      23100
# 2      24960
# 3      40000
# 4      60861
# 5      67500
# 6      67949
# 7      72264
# 8      83848
# 9      97500
# 10    110000
# 11    112713
# 12    170000
# 13    178700
# Name: Salary, dtype: int64

# %% [markdown]
# Now, let's plot which city has the maximum number of jobs.

# %%
data13.plot(kind='barh', figsize=(12, 12), color='steelblue')
plt.xlabel('Number of jobs')
plt.title(job_title_1+' jobs in Canada')

for index, value in enumerate(data13): 
    label = format(int(value), ',')
    
    plt.annotate(label, xy=(value - 0.75, index - 0.10), color='white')

plt.show()

# %% [markdown]
# Let's plao the salary range as well.

# %%
data_sal_all_2.plot(kind='barh', figsize=(15, 15), color='grey')
plt.xlabel('Salary')
plt.title(job_title_1+' salary in Canada')

for index, value in enumerate(data_sal_all_2): 
    label = format(int(value), ',') # format int with commas
    
    plt.annotate(label, xy=(value - 12000, index - 0.10), color='white')

plt.show()
